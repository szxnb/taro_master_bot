# %%
import requests
import json
import time

url = "https://oa.api2d.net/v1/chat/completions"
taro_system_prompt = "你是塔罗牌占卜大师，你会根据我所抽取的三张卡牌来对我的问题进行占卜。在回答问题的过程中还会带一些幽默。"
taro_user_question = "我和我男朋友还有可能吗？"
taro_user_card = "女教主,高塔,战车"
taro_user_content_overview = "我的问题是:" + taro_user_question +"我所抽到的三张卡牌是:" + taro_user_card + "请用1000字来回答我的问题"
taro_user_content_love = "请你帮我预测一下我未来一个月到三个月的爱情状况，我抽到的三张卡牌是:" + taro_user_card + "请用1000字来回答我的问题"
taro_user_content_career = "请你帮我预测一下我未来一个月到三个月的职业状况，我抽到的三张卡牌是:" + taro_user_card + "请用1000字来回答我的问题"
taro_user_content_finances  = "请你帮我预测一下我未来一个月到三个月的财务状况，我抽到的三张卡牌是:" + taro_user_card + "请用1000字来回答我的问题"
headers = {
   'Authorization': 'Bearer fk200296-DZuQfeFnQLL40v09VWbT8VF58i6T1E4P',
   'User-Agent': 'Apifox/1.0.0 (https://apifox.com)',
   'Content-Type': 'application/json'
}

# 总述
payload_overview = json.dumps({
   "model": "gpt-3.5-turbo",
   "messages": [
      {"role": "system", "content": taro_system_prompt},
      {"role": "user", "content": taro_user_content_overview},
   ],
   "safe_mode": False,
   "max_tokens": 2000
})

# 爱情方面
payload_love = json.dumps({
   "model": "gpt-3.5-turbo",
   "messages": [
      {"role": "system", "content": taro_system_prompt},
      {"role": "user", "content": taro_user_content_love},
   ],
   "safe_mode": False,
   "max_tokens": 2000
})

# 职业方面
payload_career = json.dumps({
   "model": "gpt-3.5-turbo",
   "messages": [
      {"role": "system", "content": taro_system_prompt},
      {"role": "user", "content": taro_user_content_career},
   ],
   "safe_mode": False,
   "max_tokens": 2000
})

# 财务方面
payload_finances = json.dumps({
   "model": "gpt-3.5-turbo",
   "messages": [
      {"role": "system", "content": taro_system_prompt},
      {"role": "user", "content": taro_user_content_finances},
   ],
   "safe_mode": False,
   "max_tokens": 2000
})



def make_request(url, headers, payload, max_retries=20):
    retries = 0
    while retries < max_retries:
        try:
            # 发送请求并获取响应
            response = requests.request("POST", url, headers = headers, data=payload)
            # 检查响应状态码是否为200
            if response.status_code == 200:
                # 解析JSON响应内容并返回
                data = response.json()
                content = data['choices'][0]['message']['content']
                return content
            else:
                # 输出错误信息
                print("Error:", response.status_code)
        except requests.exceptions.RequestException as e:
            # 输出请求异常信息
            print("Request Exception:", e)
        # 如果请求失败，则等待一段时间后重试
        retries += 1
        print(f"Retrying... {retries}/{max_retries}")
        time.sleep(1)
    
    # 如果达到最大重试次数仍然失败，则输出错误信息并返回空值
    print("Max retries reached. Request failed.")
    return None

# 调用方法
print("总述:\n"  + make_request(url, headers, payload))
print("----------------------------------------------")
print("爱情方面:\n" + make_request(url, headers, payload_love))
print("----------------------------------------------")
print("职业方面:\n" + make_request(url, headers, payload_career))
print("----------------------------------------------")
print("财务方面:\n" + make_request(url, headers, payload_finances))
# Out:
# 总述当啦拉塔卡牌被揭示时，表明着许多不稳定和紧张的局面。它预示着一场突如其来的改变，或者一些深埋在地底的问题即将浮出水面。这是一种解放性的破坏，它会打破你旧有的思维方式，带来新的视野和可能性。在感情方面，高塔可能意味着两人之间存在着一些不可避免的裂痕，或者一些长期积累的问题即将爆发。这并不意味着一定会分手，而是暗示着需要面对现实，直面问题，以寻找解决之道。
#
# 而女教主代表着智慧、理性和内在的平衡。她象征着对自我和他人的深刻理解，以及在困难时刻保持镇定与清晰头脑的能力。女教主的出现说明你需要运用内在的智慧和理性来面对眼前的困境，而不是被情绪所左右。这可能需要更加沉稳地思考问题根源，审视自身和他人的需求，寻找双方之间的平衡点。
#
# 最后，战车是代表了胜利、决心和前行的力量。它象征着面对挑战时的勇气和决心，以及不畏艰险地向前迈进。战车的出现表明，无论遇到什么困难和挑战，只要你们能够保持决心和勇气，共同努力去解决问题，你们就有可能克服障碍，赢得胜利，并且走向更加稳固的关系。
#
# 综合来看，虽然高塔的出现可能暗示着一些困难和危机，但女教主和战车的存在也带来了智慧、平衡和决心。只要你们能够以冷静理智的态度面对问题，共同努力解决困难，坦诚沟通，相互支持，相信你们之间的感情还是有可能继续发展下去的。记住，每一次的风波都是为了让你们更加坚强，更加珍惜彼此。愿你们能够携手共渡难关，战胜一切困难，走向更加美好的未来。祝你们幸福！
# ----------------------------------------------
# 爱情方面哦呦，看来你对爱情的期待值蛮高嘛！让我来用这三张卡牌为你揭开未来爱情的面纱吧。
#
# 首先是女教主，这张牌代表着智慧、直觉和内在的力量。在爱情领域，女教主暗示着你将会遇到一个很有智慧、有内涵的人，他可能会在你生活中扮演着重要的角色，给你提供意见和指导。他可能看似沉稳，但内心充满激情和温柔，会让你感受到爱情的暖意。
#
# 接着是高塔，嗯，这张牌有些不详的预兆，可能意味着在未来的一个月到三个月里，你会面临一些不稳定的状况或者突发的改变。在爱情方面，高塔暗示着可能会有一些戏剧性的转折或者冲突出现，可能是因为彼此观念不合，或者是外部因素的影响。不过，留得青山在，不怕没柴烧，有些挫折也许是为了更好的关系。
#
# 最后是战车，这张牌代表着胜利、决心和掌控力。在爱情方面，战车预示着即将迎接新的开始和胜利，你将拥有足够的决心和勇气去面对挑战，克服困难。也许在未来的一个月到三个月里，你会通过坚定的信念和努力，得到自己心仪的爱情，收获幸福与快乐。
#
# 综合三张牌的含义，未来的一个月到三个月里，你可能会遇到一位智慧、温暖的人，但在这段感情中也可能会经历一些起伏和挑战。不过，只要保持积极的心态，坚定的决心，相信自己，那么最终的胜利和幸福一定会属于你。愿你在未来的感情旅程中，能够收获真挚的爱与甜蜜的果实。祝福你！
# ----------------------------------------------
# 职业方面哦~看来你抽到了女教主、高塔和战车这三张卡牌，让我来为你解读一下吧。
#
# 首先是女教主，这张卡象征着智慧、灵感和洞察力。在财务方面，女教主提醒你要以理性和明智的态度来管理财务，不要被情绪左右，要保持冷静和理性的思考。这个月到三个月期间，你可能会遇到需要理性分析和决策的财务问题，所以请务必保持清醒的头脑，不要轻信他人的建议，要依靠自己的智慧来做出正确的决策。
#
# 接下来是高塔，这张卡象征着改变、突破和重生。在财务方面，高塔可能代表着某种突发的变化或者挑战，可能是意外的支出、投资亏损或者职业方面的变动。虽然这种变化可能会让你感到不安，但是高塔也提醒你，变化是必然的，它可能为你带来新的机遇和改善财务状况的可能性。请保持乐观的心态，相信自己有能力克服任何困难。
#
# 最后是战车，这张卡代表着胜利、奋斗和目标的实现。在财务方面，战车预示着你将会迎来财务上的成功和突破，你将会取得一定的成就和进展。这个月到三个月期间，如果你能保持奋斗的精神、全力以赴地去追求自己的目标和梦想，那么财务状况将会有所改善，你将会收获胜利和成功的喜悦。
#
# 综合这三张卡的含义来看，未来一个月到三个月的时间里，你可能会面临一些财务上的挑战和变化，但只要你保持冷静、乐观和努力拼搏，你将会战胜困难，取得成功和进步。记住，命运掌握在自己手中，相信自己，你一定能够度过这段时期，迎来更好的财务状况！加油！
# ----------------------------------------------
# Request Exception: HTTPSConnectionPool(host='oa.api2d.net', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))
# Retrying... 1/20
# 财务方面哦哦，看来你未来的财务状况可能会有些波折呢。让我来为你解读一下这三张卡牌吧。
#
# 首先是女教主，她代表着智慧、创造力和直觉。这张卡牌告诉我们，你在财务方面可能需要运用你的智慧和洞察力来做出决策。或许有些投资或理财计划需要你多加思考和策划，不要被表面的诱惑蒙蔽了你的判断力。
#
# 接着是高塔，这张卡牌通常代表突然的变化、意外的挑战或者需要突破的障碍。在财务方面，可能会有一些突发事件或者不可预测的支出出现，让你感到困惑和不安。但是不要担心，高塔的倒塌反而会为你带来新的机会和挑战。或许这是一个警示，让你在财务上保持警惕，做好应对突发情况的准备。
#
# 最后是战车，这张卡牌象征着胜利、成功和克服困难。无论你在未来的一个月到三个月里遇到了什么样的挑战，战车都鼓励你勇敢地面对，坚定地前行。你可能需要调整自己的财务策略，采取更加果断和积极的行动来应对变化和挑战。只要你保持冷静、有信心，并且勇于迎接挑战，最终你将赢得胜利，实现财务上的成功。
#
# 综合这三张卡牌的解读，我想告诉你，在未来的一个月到三个月里，可能会遇到一些挑战和变化，需要你运用智慧和勇气来克服，但同时也会有成功的机会等待着你。记住，命运掌握在自己手中，相信自己的力量，勇敢地面对未来吧！祝你好运！
